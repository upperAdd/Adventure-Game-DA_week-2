# %%
#Author Titi 
#copyright The developer academy bootcamp

import sys
import time

a = 2
b = 0.3

#classes colours for conversation text
#Green = "\033[32m"         for T person
#Yellow = "\033[33m"        for S person
#Blue  = "\033[34m"         for Q person
#Magenta = "\033[35m"       for P person
#Cyan  = "\033[36m"         for N person
#LightRed = "\033[91m"      for Y person
#LightMagenta = "\033[95m"  for V person
#White = "\033[97m"         for text sentence/ story line



# Creating Intro

def intro():
    print()
    print("\033[97m" + "COCONUT TREE EVERYWHERE")
    time.sleep(a)
    print("\033[97m" + "Pink, powdery and silky sand scrunched beneath my feets")
    time.sleep(a)
    print("\033[97m" + "The waves crawling gently drenching the sand")
    time.sleep(a)
    print("\033[97m" + "Smell salty breeze fill my lung's")
    time.sleep(a)
    print("\033[97m" + "Seagull fighting over food")
    time.sleep(a)
    print("\033[97m" + "WELCOME AT NATIONAL PARK KOMODO BEACH")
    time.sleep(a)
    print()

# Creating Loop
    T1 = "Ah, i'm in Pink Komodo beach?!"
    for character in T1:
        sys.stdout.write("\033[92m" + character )
        sys.stdout.flush()
        time.sleep(b)
    time.sleep(1.0)
    print()
    print("\033[97m" + "You saw direction sign next to big rainbow umbrella")
    time.sleep(a)
    print("\033[97m" + "SNORKEL WITH SEA TURTLES with green color and DIVING WITH MANTA RAY with yellow color")
    time.sleep(a)
    print()
    T2 = "Wow, both seems tempting to choose?!"
    for character in T2:
        sys.stdout.write("\033[32m" + character)
        sys.stdout.flush()
        time.sleep(b)
    time.sleep (1.0)
    print()
    time.sleep(b)
    print("\033[97m" + "Two path are revealed:")
    time.sleep(b)
    print()
    print("\033[97m" + "Path #1: Follow the green sign next to big rainbow umbrella for go to Snorkel Site.")
    time.sleep(b)
    print("\033[97m" + "Path #2: Follow the yellow sign next to big rainbow umbrella for go to Diving Site.")
    time.sleep(b)
    print()
    print("\033[97m" + "Which path you will choose? (1 or 2?): ")
    firstPath = input("Which path you will choose? (1 or 2?): ")
    if firstPath == '1':
        print()
        Path1()
    elif firstPath == '2':
        print()
        Path2()
    

def Path1():
    print("\033[97m" + "You follow the green sign next to big rainbow umbrella")
    time.sleep(a)
    print()
    T3 = "Aah,It's quite near! Just 300 meter to go there!"
    for character in T3:
        sys.stdout.write("\033[32m" + character)
        sys.stdout.flush()
        time.sleep(b)
    time.sleep(1.0)
    print()
    print("\033[97m" + "You finally arrived at snorkel site")
    time.sleep(a)
    print("\033[97m" + "A young lad approach you with warm smile")
    time.sleep(a)
    print()
    S1 = "Hiya ...How i can help you today?"
    for character in S1:
        sys.stdout.write("\033[33m" + character)
        sys.stdout.flush()
        time.sleep(b)
    time.sleep(1.0)
    print()
    T4 = "Ah yes, I'm interest to snorkel. Can you tell me the cost and can we rent the equipment(google and fins)?" 
    for character in T4:
        sys.stdout.write("\033[32m" + character)
        sys.stdout.flush()
        time.sleep(b)
    time.sleep(1.0)
    print()
    T5 = "Will be it included or will be separate cost please?"
    for character in T5:
        sys.stdout.write("\033[32m" + character)
        sys.stdout.flush()
        time.sleep(b)
    time.sleep(1.0)
    print()
    S2 = "So for the snorkel it just cost £49.99 for both of you and include with rented equipment ( life jacket, googles, and fin)." 
    for character in S2:
        sys.stdout.write("\033[33m" + character)
        sys.stdout.flush()
        time.sleep(b)
    time.sleep(1.0)
    print()
    S3 = "We also have 2 snorkel site, sea turtles and coral garden."
    for character in S3:
        sys.stdout.write("\033[33m" + character)
        sys.stdout.flush()
        time.sleep(b)
    time.sleep(1.0)
    print()
    print("\033[97m" + "Which site you will choose? (sea turtle or coral garden?): ")
    secondPath = input("Which site you will choose? (sea turtle or coral garden?): ")
    if secondPath == 'sea turtle':
        print()
        Path1_1()
    elif secondPath == 'coral garden':
        print()
        Path1_2()


def Path1_1():
    print()
    print("\033[97m" + "You go into blue sport cabin boat in pier")
    time.sleep(a)
    print()
    P1 = "Hiya ...Thank you for choosing snorkel with us. Can i ask, can you swim?"
    for character in P1:
        sys.stdout.write("\033[35m" + character)
        sys.stdout.flush()
        time.sleep(b)
    time.sleep(1.0)

    question1 = input("Can you swim? (yes or no): ")
    print()
    if question1 == 'no' or question1 == 'n':
        print()
        P2 = "I would like to suggest you go to coral garden site that more shallow and less currents for your own safety."
        for character in P2:
            sys.stdout.write("\033[35m" + character)
            sys.stdout.flush()
            time.sleep(b)
        time.sleep(1.0)
        print()
    question3 = input("Would you like to play again? (yes or no):")
    print()
    if question3 == 'no' or question3 == 'n':
        print()
        print("\033[97m" + "Thanks for playing")
        time.sleep (5.0)
    elif question3 == 'yes' or question3 == 'y':
        intro()


    elif question1 == 'yes' or question1 == 'y':
        print()
        P3 = "Perfect! i will explain you more detail about the Sea turtle site."
        for character in P3:
            sys.stdout.write("\033[35m" + character)
            sys.stdout.flush()
            time.sleep(b)
        time.sleep(1.0)
        print()
        print("\033[97m" + "After couple minutes listening detail situation Sea turtle site")
        time.sleep(a)
        print("\033[97m" + "The captain boat ask everyone to get ready")
        time.sleep(a)
        P4 = "So the fin and googles is in white container, Please help yourself!"
        for character in P4:
            sys.stdout.write("\033[35m" + character)
            sys.stdout.flush()
            time.sleep(b)
        time.sleep(1.0)
        print()
        T6 = "Okay, will do that"
        for character in T6:
            sys.stdout.write("\033[32m" + character)
            sys.stdout.flush()
            time.sleep(b)
        time.sleep(1.0)
        print()
        print("\033[97m" + "Journey snorkling with Sea turtle begin!")
        time.sleep(a)
        print("\033[97m" + "Thanks for playing")

def Path1_2():
    print()
    print("\033[97m" + "You go to blue tent that have small cafe next to")
    time.sleep(a)
    print()
    Q1 = "Hello there!.. would you like to snorkel see coral garden?"
    for character in Q1:
        sys.stdout.write("\033[34m" + character)
        sys.stdout.flush()
        time.sleep(b)
    time.sleep(1.0)
    print()
    T7 = "Yes please!"
    for character in T7:
        sys.stdout.write("\033[32m" + character)
        sys.stdout.flush()
        time.sleep(b)
    time.sleep(1.0)
    print()
    Q2 = "Help yourself to find the right size for fin and googles in that wood boxes,.. "
    for character in Q2:
        sys.stdout.write("\033[34m" + character)
        sys.stdout.flush()
        time.sleep(b)
    time.sleep(1.0)
    print()
    Q3 = "..,and after you finished please returned in white plastic container,it's the opposite of wood boxes"
    for character in Q3:
        sys.stdout.write("\033[34m" + character)
        sys.stdout.flush()
        time.sleep(b)
    time.sleep(1.0)
    print()
    Q4 = "The duration for snorkel will be 3 hours maximum more than that will be additional cost £1 every 10 minutes."
    for character in Q4:
        sys.stdout.write("\033[34m" + character)
        sys.stdout.flush()
        time.sleep(b)
    time.sleep(1.0)
    print()
    Q5 = "Are you okay with this?!"
    for character in Q5:
        sys.stdout.write("\033[34m" + character)
        sys.stdout.flush()
        time.sleep(b)
    time.sleep(1.0)
    print()
    T8 = "Yes, of course!"
    for character in T8:
        sys.stdout.write("\033[32m" + character)
        sys.stdout.flush()
        time.sleep(b)
    time.sleep(1.0)
    print()
    Q6 = "Perfect! Enjoyed!"
    for character in Q6:
        sys.stdout.write("\033[34m" + character)
        sys.stdout.flush()
        time.sleep(b)
    time.sleep(1.0)
    print()
    print("\033[97m" + "Thanks for playing")

def Path2():
    print("\033[97m" + "You follow the yellow sign next to big rainbow umbrella")
    time.sleep(a)
    print("\033[97m" + "After walk half mile you saw plenty dive centres that offer service")
    time.sleep(a)
    print("\033[97m" + "Several cafe and restaurant offer coconut water and delicious cuisine snack that make mouth watering people that passingby ")
    time.sleep(a)
    print("\033[97m" + "After couple minutes discuss and browsing, you finally decide to go to DOLPHIN DIVE CENTRE")
    time.sleep(a)
    N1 = "Olla... Do you want to dive?"
    for character in N1:
        sys.stdout.write("\033[36m" + character)
        sys.stdout.flush()
        time.sleep(b)
    time.sleep(1.0)
    print()
    T9 = "Yes, we are!"
    for character in T9:
        sys.stdout.write("\033[32m" + character)
        sys.stdout.flush()
        time.sleep(b)
    time.sleep(1.0)
    print()
    N2 = "Are you both have diving license?"
    for character in N2:
        sys.stdout.write("\033[36m" + character)
        sys.stdout.flush()
        time.sleep(b)
    time.sleep(1.0)
    print()
    question2 = input("Have diving license? (yes or no): ")
    print()
    if question2 == 'no' or question2 == 'n':
        print()
        N3 = "Unfortunately, I would like to suggest you to have snorkel for your own safety."
        for character in N3:
            sys.stdout.write("\033[36m" + character)
            sys.stdout.flush()
            time.sleep(b)
        time.sleep(1.0)
        print()
    question4 = input("Would you like to play again? (yes or no):")
    print()
    if question4 == 'no' or question4 == 'n':
        print()
        print("\033[97m" + "Thanks for playing")
        time.sleep (5.0)

    elif question4 == 'yes' or question4 == 'y':
        intro()
    
    
    elif question2 == 'yes' or question2 == 'y':
        print()
        N3 = "Perfect! So we have special price for couple and it's include stay overnight at our hostel."
        for character in N3:
            sys.stdout.write("\033[36m" + character)
            sys.stdout.flush()
            time.sleep(b)
        time.sleep(1.0)
        print()
        T10 = "How much is it? and how much the cost if we just dive only please?"
        for character in T10:
            sys.stdout.write("\033[32m" + character)
            sys.stdout.flush()
            time.sleep(b)
        time.sleep(1.0)
        print()
        N4 = "for diving and stay overnight plus meal for you and your partner will be £200"
        for character in N4:
            sys.stdout.write("\033[36m" + character)
            sys.stdout.flush()
            time.sleep(b)
        time.sleep(1.0)
        print()
        N5 = "if just dive for both of you for 2 hours will be £99.99"
        for character in N5:
            sys.stdout.write("\033[36m" + character)
            sys.stdout.flush()
            time.sleep(b)
        time.sleep(1.0)
        print()
        N6 = "are you interest with our offer? Which one is it?"
        for character in N6:
            sys.stdout.write("\033[36m" + character)
            sys.stdout.flush()
            time.sleep(b)
        time.sleep(1.0)
        print()
        T11 = "we will take the special price, please."
        for character in T11:
            sys.stdout.write("\033[32m" + character)
            sys.stdout.flush()
            time.sleep(b)
        time.sleep(1.0)
        print()
        N7 = "Fabs! So we have 2 dive site, one is mola-mola and the other one is manta ray"
        for character in N7:
            sys.stdout.write("\033[36m" + character)
            sys.stdout.flush()
            time.sleep(b)
        time.sleep(1.0)
        print()
        N8 = "Which one you would like to? (Mola-mola or Manta Ray?)"
        for character in N8:
            sys.stdout.write("\033[36m" + character)
            sys.stdout.flush()
            time.sleep(b)
        time.sleep(1.0)
        print()
        thirdPath = input("Which one you interest? (Mola-mola or Manta Ray?): ")
        print()
        if thirdPath == 'mola-mola'or thirdPath == 'mola':
            print()
            Path2_1()
        
        elif thirdPath == 'manta ray' or thirdPath == 'manta':
            print()
            Path2_2()

def Path2_1():
    print()
    print("\033[36m" + "please follow Alex our instructor")
    time.sleep(1.0)
    T12 = "Okay, i got you!"
    for character in T12:
        sys.stdout.write("\033[32m" + character)
        sys.stdout.flush()
        time.sleep(b)
    time.sleep(1.0)
    print()
    V1 = "Good morning! So now i will to explain little bit about the currents and visibility about our diving site."
    for character in V1:
        sys.stdout.write("\033[95m" + character)
        sys.stdout.flush()
        time.sleep(b)
    time.sleep(1.0)
    print()
    T13 = "Morning! ah.. cool!"
    for character in T13:
        sys.stdout.write("\033[32m" + character)
        sys.stdout.flush()
        time.sleep(b)
    time.sleep(1.0)
    print()
    print()
    print("\033[97m" + "Refreshemnt lesson at pool started and went well")
    time.sleep(a)
    print("\033[97m" + "The boat start depart and after 30 minutes the engine stop")
    time.sleep(a)
    print()
    V2 = "We already arrive at mola - mola site."
    for character in V2:
        sys.stdout.write("\033[95m" + character)
        sys.stdout.flush()
        time.sleep(b)
    time.sleep(1.0)
    print()    
    V3 = "Please follow your dive buddy and if you heard the oxygen tank being knock twice please prepare to go up."
    for character in V3:
        sys.stdout.write("\033[95m" + character)
        sys.stdout.flush()
        time.sleep(b)
    time.sleep(1.0)
    print()    
    print("\033[97m" + "Nemo, Royal blue fish- DORY, Moral eel being swim shy near pink and purple beautifull anemone")
    time.sleep(a)
    print("\033[97m" + "After couple minutes, one of buddy give sign that mola - mola group being swim toward to us and give instruction we go more deeper")
    time.sleep(a)
    print("\033[97m" + "Thanks for playing")


def Path2_2():
    print()
    print("\033[36m" + "please follow our James instructor")
    time.sleep(1.0)
    T14 = "Ah okay, thank you!"
    for character in T14:
        sys.stdout.write("\033[32m" + character)
        sys.stdout.flush()
        time.sleep(b)
    time.sleep(1.0)
    print()
    Y1 = "Hi mate! Welcome on board to our MIGHTY BOAT that will bring us to Manta Ray site."
    for character in Y1:
        sys.stdout.write("\033[91m" + character)
        sys.stdout.flush()
        time.sleep(b)
    time.sleep(1.0)
    print()    
    Y2 = "As always i will give short brief regarding what we can do during diving, .." 
    for character in Y2:
        sys.stdout.write("\033[91m" + character)
        sys.stdout.flush()
        time.sleep(b)
    time.sleep(1.0)
    print()    
    Y3 = "..,and please pay attention on anything for example like strong current that may suddenly occur or any sound tank being hitted."
    for character in Y3:
        sys.stdout.write("\033[91m" + character)
        sys.stdout.flush()
        time.sleep(b)
    time.sleep(1.0)
    print()    
    Y4 = "So when your heard sound tank being hit with this, it's means above you or near you will comes Manta Ray, that will be either comes in pair or group or just only one ."
    for character in Y4:
        sys.stdout.write("\033[91m" + character)
        sys.stdout.flush()
        time.sleep(b)
    time.sleep(1.0)
    print()    
    Y5= "Please do not swim close to them because manta ray has poison tail."
    for character in Y5:
        sys.stdout.write("\033[91m"+ character)
        sys.stdout.flush()
        time.sleep(b)
    time.sleep(1.0)
    print()
    Y6= "Please keep checking your oxigen level if near close 2 bar, give signal to your buddy that you ascending."
    for character in Y6:
        sys.stdout.write("\033[91m" + character)
        sys.stdout.flush()
        time.sleep(b)
    time.sleep(1.0)
    print()
    Y7= "So is there any question so far?"
    for character in Y7:
        sys.stdout.write("\033[91m" + character)
        sys.stdout.flush()
        time.sleep(b)
    time.sleep(1.0)
    print()
    T15 = "Nope! It's crystal clear."
    for character in T15:
        sys.stdout.write("\033[32m" + character)
        sys.stdout.flush()
        time.sleep(b)
    time.sleep(1.0)
    print()
    Y8= "Brilliant! so now we can start our journey to descending!"
    for character in Y8:
        sys.stdout.write("\033[91m" + character)
        sys.stdout.flush()
        time.sleep(b)
    time.sleep(1.0)
    print()
    print("\033[97m" + "Thank you for playing! ")



# Main Function 
print()
print("\033[32m" + "Wow, where am i?")
time.sleep(a)
print("\033[32m" + "Seems like in tropical islands ...")
time.sleep(a)
print()
print("\033[97m" + "would you like to play? ")
startGame = input("Would you like to play? (yes/no): ")
if startGame == "no" or startGame == "n":
    print("\033[97m" + "Maybe next time")
    time.sleep(3)
elif startGame == "yes" or startGame == "y":
    intro()
# Out:
# Wow, where am i?
# Seems like in tropical islands ...
#
# would you like to play?
#
# COCONUT TREE EVERYWHERE
# Pink, powdery and silky sand scrunched beneath my feets
# The waves crawling gently drenching the sand
# Smell salty breeze fill my lung's
# Seagull fighting over food
# WELCOME AT NATIONAL PARK KOMODO BEACH
#
# Ah, i'm in Pink Komodo beach?!
# You saw direction sign next to big rainbow umbrella
# SNORKEL WITH SEA TURTLES with green color and DIVING WITH MANTA RAY with yellow color
#
# Wow, both seems tempting to choose?!
# Two path are revealed:
#
# Path #1: Follow the green sign next to big rainbow umbrella for go to Snorkel Site.
# Path #2: Follow the yellow sign next to big rainbow umbrella for go to Diving Site.
#
# Which path you will choose? (1 or 2?):
#
# You follow the yellow sign next to big rainbow umbrella
# After walk half mile you saw plenty dive centres that offer service
# ...

# %%
print('\033[93m' + 'output')
print('\033[91m' + 'output')
print('\033[94m' + 'output')
print('\033[95m' + 'output')
print('\033[92m' + 'output')


#Classing colour for text
    Default      = "\033[39m"
	Black        = "\033[30m"
	Red          = "\033[31m"
	Green        = "\033[32m" myself T
	Yellow       = "\033[33m"  S person
	Blue         = "\033[34m"	q person
	Magenta      = "\033[35m" P person
	Cyan         = "\033[36m"	n person
	LightGray    = "\033[37m"
	DarkGray     = "\033[90m"
	LightRed     = "\033[91m" y person
	LightGreen   = "\033[92m"
	LightYellow  = "\033[93m"
	LightBlue    = "\033[94m"
	LightMagenta = "\033[95m" V person
	LightCyan    = "\033[96m" 
	White        = "\033[97m" text sentence
# Out:
# output
# output
# output
# output
# output
